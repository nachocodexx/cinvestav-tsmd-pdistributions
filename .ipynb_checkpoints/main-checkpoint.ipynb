# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import binom
from scipy import stats
from scipy.interpolate import UnivariateSpline
import seaborn as sns
def Vector(*args):
    return np.array(args)
default_style = lambda c : {**c,'color':'white'}

# %% [markdown]
# ## Binomial distribution

# %%
plot_pdistribution(
#     rand_fx   = np.random.binomial,
    rand_fx   = stats.binom.rvs,
    fx        = lambda x,_,params: stats.binom.pmf(x,n = params['n'],p=params['p']),
    pd_params = [
#         Binomial
        {'n':20,'p':0.5,'size':10000},
#         {'n':20,'p':0.8,'size':10000},
#         {'n':20,'p':0.3,'size':10000}
    ], 
    styles = [
        default_style({'edgecolor':"red","hatch":"/",'alpha':.8}),
#         default_style({'edgecolor':"green","hatch":"*",'alpha':.5}),
#         default_style({'edgecolor':"black","hatch":".",'alpha':.5}),
    ]
)

# %%
rand_state = np.random.RandomState(1234)
x = stats.binom.rvs(size=1000,p=.5,n=20,random_state=rand_state)
ax = sns.boxplot(x=x)

# %% [markdown]
# ## Poisson distribution

# %%
plot_pdistribution(
#     rand_fx   = np.random.poisson,
    rand_fx   = stats.poisson.rvs,
    fx        = lambda x,data,params: stats.poisson.pmf(x,mu=params['mu']  ),
    pd_params = [
#       Poisson  
        {'mu':5,'size':10000},
#         {'lam':10,'size':10000},
#         {'lam':5,'size':10000},
#       Chi-square
#         {'df':100,'size':10000},
#         {'df':30,'size':10000},
#         Binomial
#         {'n':20,'p':0.5,'size':100000},
#         {'n':20,'p':0.8,'size':100000}
    ], 
    styles = [
        default_style({'edgecolor':"red","hatch":"/",'alpha':.8}),
#         default_style({'edgecolor':"green","hatch":"*",'alpha':.5}),
#         default_style({'edgecolor':"black","hatch":".",'alpha':.5}),
    ]
)
# plt.show()

# %% [markdown]
# ## Guassian distribution

# %%
plot_pdistribution(
#     rand_fx   = np.random.normal,
    rand_fx   = stats.norm.rvs,
    fx        = lambda x,data,params: stats.norm.pdf(x,loc=params['loc'],scale=params['scale']  ),
    pd_params = [
        {'size':10000,'loc':0,'scale':2},
        {'size':10000,'loc':6,'scale':1.5},
        {'size':10000,'loc':-5,'scale':1.5},
    ], 
    styles = [
        default_style({'edgecolor':"red","hatch":"/",'alpha':.8}),
        default_style({'edgecolor':"green","hatch":"*",'alpha':.5}),
        default_style({'edgecolor':"black","hatch":".",'alpha':.5}),
    ]
)

# %% [markdown]
# ## T-distribution

# %%
plot_pdistribution(
    rand_fx   = stats.t.rvs,
    fx        = lambda x,data,params: stats.t.pdf(x,params['df'],loc=params['loc'],scale=params['scale']),
    pd_params = [
        {'size':1000,'df':500,'loc':2,'scale':2},
    ], 
    styles = [
#         default_style({'edgecolor':"red","hatch":"/",'alpha':.8}),
#         default_style({'edgecolor':"green","hatch":"*",'alpha':.5}),
        default_style({'edgecolor':"black","hatch":".",'alpha':.5}),
    ]
)

# %% [markdown]
# ## Chi-squared distribution

# %%
plot_pdistribution(
    rand_fx   = stats.chi2.rvs,
    fx        = lambda x,data,params: stats.chi2.pdf(x,params['df'],loc=params['loc'],scale=params['scale']),
    pd_params = [
        {'size':1000,'df':500,'loc':2,'scale':2},
        {'size':1000,'df':500,'loc':4,'scale':3},
    ], 
    styles = [
        default_style({'edgecolor':"red","hatch":"/",'alpha':.8}),
#         default_style({'edgecolor':"green","hatch":"*",'alpha':.5}),
        default_style({'edgecolor':"black","hatch":".",'alpha':.5}),
    ]
)

# %% [markdown]
# ## F - distribution

# %%
plot_pdistribution(
    rand_fx   = stats.f.rvs,
    fx        = lambda x,data,params: stats.f.pdf(x,
                                                  dfn  = params['dfn'],
                                                  dfd  = params['dfd'],
                                                  loc=params['loc'],
                                                  scale=params['scale']
                                                 ),
    pd_params = [
        {'size':1000,'dfn':100,'dfd':10,'loc':2,'scale':2},
        {'size':1000,'dfn':10,'dfd':200,'loc':4,'scale':3},
    ], 
    styles = [
        default_style({'edgecolor':"red","hatch":"/",'alpha':.8}),
#         default_style({'edgecolor':"green","hatch":"*",'alpha':.5}),
        default_style({'edgecolor':"black","hatch":".",'alpha':.5}),
    ]
)

# %%
# stats.poisson.pmf(1,mu=1)
# data = np.random.poisson(lam=500,size=1000)
# sns.boxplot(y=data)
# data
# Out:
# 0.36787944117144233

# %% [markdown]
# # Utils

# %%
def plot_pdistribution(**kwargs):
    pd_params  = kwargs.get("pd_params",[{'n':20,'p':0.5,'size':10000}] )
    styles     = kwargs.get("styles",[])
    rand_state = np.random.RandomState(1234)
    step       = kwargs.get("step",1)
    num_plots  = len(pd_params)
    rand_fx    = kwargs.get("rand_fx",np.random.binomial)
    fx         = kwargs.get('fx',None)
    data       = list(map(lambda c:rand_fx(**c,random_state=rand_state),pd_params))
    _,ax       = plt.subplots()
    xs         = list(map(lambda d: np.arange(d.min(), d.max()),data))
    if(fx):
        ys = list( map( lambda x: fx(*x), zip(xs,data,pd_params)  ))
        for x,y in zip(xs,ys):
            ax.plot(x,y,color="black")
        
    for datum,style in zip(data,styles):
#         print(style)
        ax.hist(datum,bins=50,**style,density=True)
